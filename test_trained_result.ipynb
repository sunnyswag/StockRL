# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import datetime
import time

# %matplotlib inline
from utils import config
from utils.backtest import backtest_stats, backtest_plot, get_baseline
# Out:
# C:\Users\henhaoqi\anaconda3\lib\site-packages\pyfolio\pos.py:27: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   'Module "zipline.assets" not found; multipliers will not be applied'

# %% [markdown]
# ## 数据读取

# %%
a2c_account_value = pd.read_csv("./trained_result/A2C/df_account_value_a2c.csv")
ddpg_account_value = pd.read_csv("./trained_result/DDPG/df_account_value_ddpg.csv")
ppo_account_value = pd.read_csv("./trained_result/PPO/df_account_value_ppo.csv")
sac_account_value = pd.read_csv("./trained_result/SAC/df_account_value_sac.csv")
td3_account_value = pd.read_csv("./trained_result/TD3/df_account_value_td3.csv")

# %% [markdown]
# ## 获取 baseline 的结果

# %%
baseline_df = get_baseline(config.SSE_50_INDEX, 
              start="20190101",
              end="20210101")
baseline_stats = backtest_stats(baseline_df, value_col_name='close')
# Out:
# --- 开始下载 ----
# --- 下载完成 ----
# DataFrame 的大小:  (487, 8)
# Annual return          0.271107
# Cumulative returns     0.589776
# Annual volatility      0.189096
# Sharpe ratio           1.366667
# Calmar ratio           1.487275
# Stability              0.618053
# Max drawdown          -0.182284
# Omega ratio            1.286287
# Sortino ratio          1.953108
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.078570
# Daily value at risk   -0.022798
# dtype: float64

# %%
start_close_value = baseline_df.iloc[0]['close']
baseline_df['processed_close'] = ((baseline_df['close'] - start_close_value)/start_close_value + 1) * 1e+6

# %%
baseline_df.head()
# Out:
#          date        tic       open       high        low      close  \
# 0  2019-01-02  000016.SH  2262.7908  2298.1805  2301.0552  2252.7479
# 1  2019-01-03  000016.SH  2269.2430  2259.4825  2287.7778  2253.9433
# 2  2019-01-04  000016.SH  2314.6466  2252.7449  2316.3528  2249.3658
# 3  2019-01-07  000016.SH  2314.3193  2329.0316  2331.6031  2306.8979
# 4  2019-01-08  000016.SH  2305.1708  2312.1705  2312.1705  2298.9548
#
#        volume  day  processed_close
# 0  20880697.0    2     1.000000e+06
# 1  18895240.0    3     1.000531e+06
# 2  25900596.0    4     9.984987e+05
# 3  25278948.0    0     1.024037e+06
# 4  18131160.0    1     1.020511e+06

# %% [markdown]
# ## 展示最终的结果

# %%
result_account_value = pd.DataFrame(data = {
                                        'a2c': a2c_account_value['total_assets'], 
                                        'ddpg': ddpg_account_value['total_assets'],
                                        'ppo': ppo_account_value['total_assets'],
                                        'sac': sac_account_value['total_assets'],
                                        'td3': td3_account_value['total_assets'],
                                        'baseline': baseline_df['processed_close']})

# %%
result_account_value = result_account_value.iloc[:-1].apply(lambda x : (x - 1e+6)/1e+6)

# %%
result_account_value.head()
# Out:
#         a2c      ddpg       ppo       sac       td3  baseline
# 0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1 -0.000269 -0.000502 -0.000259 -0.001233 -0.000103  0.000531
# 2  0.004095  0.004911  0.002477  0.005780  0.006844 -0.001501
# 3  0.005295  0.005382  0.002729  0.005793  0.007314  0.024037
# 4  0.002303 -0.000069  0.001246  0.001629  0.004409  0.020511

# %%
result_account_value.to_csv("./trained_result/result_account_value.csv", index=False)
result_account_value.plot(figsize = (20, 10))

# %% [markdown]
# ## 展示 A2C 的回测结果

# %%
print("和 {} 指数进行比较".format(config.SSE_50_INDEX[0]))
backtest_plot(a2c_account_value,
        baseline_start="20190101",
        baseline_end="20210101",
        baseline_ticker=config.SSE_50_INDEX,
        value_col_name = 'total_assets'
      )
# Out:
# 和 000016.SH 指数进行比较
# --- 开始下载 ----
# --- 下载完成 ----
# DataFrame 的大小:  (487, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2019-01-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-12-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>23</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>46.371%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>108.493%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>36.254%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.23</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>1.29</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.89</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-35.83%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.31</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.87</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.27</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-4.39%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.31</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.69</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>35.83</td>
#       <td>2020-02-26</td>
#       <td>2020-03-24</td>
#       <td>2020-07-02</td>
#       <td>92</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>16.76</td>
#       <td>2019-04-08</td>
#       <td>2019-06-06</td>
#       <td>2019-06-24</td>
#       <td>56</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>16.76</td>
#       <td>2020-07-10</td>
#       <td>2020-10-09</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>10.92</td>
#       <td>2020-01-23</td>
#       <td>2020-02-04</td>
#       <td>2020-02-18</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>6.42</td>
#       <td>2019-09-23</td>
#       <td>2019-10-21</td>
#       <td>2019-11-06</td>
#       <td>33</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\henhaoqi\anaconda3\lib\site-packages\pyfolio\tears.py:907: UserWarning: Passed returns do not overlap with anyinteresting times.
#   'interesting times.', UserWarning)

# %% [markdown]
# ## 展示 DDPG 的回测结果

# %%
print("和 {} 指数进行比较".format(config.SSE_50_INDEX[0]))
backtest_plot(ddpg_account_value,
        baseline_start="20190101",
        baseline_end="20210101",
        baseline_ticker=config.SSE_50_INDEX,
        value_col_name = 'total_assets'
      )
# Out:
# 和 000016.SH 指数进行比较
# --- 开始下载 ----
# --- 下载完成 ----
# DataFrame 的大小:  (487, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2019-01-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-12-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>23</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>50.953%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>121.264%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>30.776%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.50</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>1.62</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.92</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-31.454%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.34</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>2.19</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.33</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-3.695%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.37</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.56</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>31.45</td>
#       <td>2020-02-26</td>
#       <td>2020-03-24</td>
#       <td>2020-07-06</td>
#       <td>94</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>15.01</td>
#       <td>2019-04-22</td>
#       <td>2019-05-07</td>
#       <td>2019-07-02</td>
#       <td>52</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>11.86</td>
#       <td>2020-07-14</td>
#       <td>2020-10-09</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>10.26</td>
#       <td>2020-01-23</td>
#       <td>2020-02-04</td>
#       <td>2020-02-14</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>7.44</td>
#       <td>2019-04-08</td>
#       <td>2019-04-15</td>
#       <td>2019-04-18</td>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\henhaoqi\anaconda3\lib\site-packages\pyfolio\tears.py:907: UserWarning: Passed returns do not overlap with anyinteresting times.
#   'interesting times.', UserWarning)

# %% [markdown]
# ## 展示 PPO 的回测结果

# %%
print("和 {} 指数进行比较".format(config.SSE_50_INDEX[0]))
backtest_plot(ppo_account_value,
        baseline_start="20190101",
        baseline_end="20210101",
        baseline_ticker=config.SSE_50_INDEX,
        value_col_name = 'total_assets'
      )
# Out:
# 和 000016.SH 指数进行比较
# --- 开始下载 ----
# --- 下载完成 ----
# DataFrame 的大小:  (487, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2019-01-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-12-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>23</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>47.228%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>110.854%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>24.284%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.72</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>2.82</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.94</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-16.747%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.36</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>2.64</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.33</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.894%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.33</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.52</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16.75</td>
#       <td>2020-03-06</td>
#       <td>2020-03-24</td>
#       <td>2020-06-24</td>
#       <td>79</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>11.43</td>
#       <td>2020-01-23</td>
#       <td>2020-02-04</td>
#       <td>2020-02-18</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9.82</td>
#       <td>2019-04-22</td>
#       <td>2019-05-10</td>
#       <td>2019-06-28</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>8.38</td>
#       <td>2020-10-14</td>
#       <td>2020-11-05</td>
#       <td>2020-12-02</td>
#       <td>36</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>8.25</td>
#       <td>2019-04-08</td>
#       <td>2019-04-16</td>
#       <td>2019-04-22</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\henhaoqi\anaconda3\lib\site-packages\pyfolio\tears.py:907: UserWarning: Passed returns do not overlap with anyinteresting times.
#   'interesting times.', UserWarning)

# %% [markdown]
# ## 展示 SAC 的回测结果

# %%
print("和 {} 指数进行比较".format(config.SSE_50_INDEX[0]))
backtest_plot(sac_account_value,
        baseline_start="20190101",
        baseline_end="20210101",
        baseline_ticker=config.SSE_50_INDEX,
        value_col_name = 'total_assets'
      )
# Out:
# 和 000016.SH 指数进行比较
# --- 开始下载 ----
# --- 下载完成 ----
# DataFrame 的大小:  (487, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2019-01-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-12-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>23</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>50.722%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>120.612%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>29.477%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.54</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>1.73</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.91</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-29.239%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.35</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>2.26</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.36</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-3.533%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.35</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.60</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>29.24</td>
#       <td>2020-02-26</td>
#       <td>2020-03-24</td>
#       <td>2020-07-02</td>
#       <td>92</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>15.76</td>
#       <td>2019-04-22</td>
#       <td>2019-06-06</td>
#       <td>2019-07-29</td>
#       <td>71</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>11.12</td>
#       <td>2020-01-21</td>
#       <td>2020-02-04</td>
#       <td>2020-02-21</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>9.51</td>
#       <td>2020-07-10</td>
#       <td>2020-10-09</td>
#       <td>2020-11-10</td>
#       <td>88</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>6.07</td>
#       <td>2019-07-31</td>
#       <td>2019-08-08</td>
#       <td>2019-08-21</td>
#       <td>16</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\henhaoqi\anaconda3\lib\site-packages\pyfolio\tears.py:907: UserWarning: Passed returns do not overlap with anyinteresting times.
#   'interesting times.', UserWarning)

# %% [markdown]
# ## 展示 TD3 的回测结果

# %%
print("和 {} 指数进行比较".format(config.SSE_50_INDEX[0]))
backtest_plot(td3_account_value,
        baseline_start="20190101",
        baseline_end="20210101",
        baseline_ticker=config.SSE_50_INDEX,
        value_col_name = 'total_assets'
      )
# Out:
# 和 000016.SH 指数进行比较
# --- 开始下载 ----
# --- 下载完成 ----
# DataFrame 的大小:  (487, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2019-01-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-12-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>23</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>50.554%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>120.136%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>29.892%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.52</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>1.65</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.90</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-30.691%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.35</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>2.27</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.28</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-3.585%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.33</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.64</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>30.69</td>
#       <td>2020-02-26</td>
#       <td>2020-03-24</td>
#       <td>2020-07-02</td>
#       <td>92</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>14.82</td>
#       <td>2019-04-22</td>
#       <td>2019-06-06</td>
#       <td>2019-08-26</td>
#       <td>91</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>10.80</td>
#       <td>2020-01-23</td>
#       <td>2020-02-04</td>
#       <td>2020-02-21</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>9.45</td>
#       <td>2020-07-10</td>
#       <td>2020-07-17</td>
#       <td>2020-10-13</td>
#       <td>68</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>8.74</td>
#       <td>2020-10-13</td>
#       <td>2020-11-03</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\henhaoqi\anaconda3\lib\site-packages\pyfolio\tears.py:907: UserWarning: Passed returns do not overlap with anyinteresting times.
#   'interesting times.', UserWarning)
